# %% [markdown]
# #### Name: Andrew Shapiro
# #### Date: 10/02/2024
# #### Exercise: Project #1, Part 2: Data Exploration and Cleaning
# #### Description: This notebook will read in the Fall 2023 Non-Majors Survey Results .csv file, identify properties of the dataset, clean up the dataset to be more directed at our study focus, and then export it for future use.

# %%
import pandas as pd

# %% [markdown]
# ## 1. Read in your Project 1 assigned dataset(s) into pandas data frame(s).
# For this assignment, I have selected the **Fall 2024** dataset of the **Non-Majors Survey Results**.
# * By changing the file that is read into pandas below, the same modifications will be applied to that dataset.
# * Fall 2020 - 2024 are in the same folder and they are titled `Fall202X.csv`.

# %%
# Read the dataset into the pandas data frame.
df = pd.read_csv('Fall2024.csv')

# %% [markdown]
# ## 2. Explore the dataset using some of pandas’ properties and built-in functions.
# For this assignment, I will show my explorations and results in separate notebook cells. The list below are all of the pandas properties and built-in functions I will be exploring.
# * describe()
# * columns
# * shape
# * dtypes
# * head(), tail(), sample()
# * info()

# %% [markdown]
# ### **(a)** df.describe()
# After I ran this function on the dataframe, I was given a summary of the question 'On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?', so I believe that this would only apply to numerical data. It gave me the count, mean, standard deviation, minimum, 25-50-75 quartiles, and the maximum.
#
# From this function, I was able to grasp that there were 105 responses to the form and the average response was around 2.5.

# %%
df.describe()
# Out:
#        On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?
# count                                          92.000000
# mean                                            2.576087
# std                                             1.131310
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             5.000000

# %% [markdown]
# ### **(b)** df.columns
# After I ran this property on the dataframe, I was given an object filled with strings with all of the column names in the dataset. I noticed that there were many of the same question (ex. 'How did you hear about County College of Morris?') but showed each of the answer choices as its own question in the data table.

# %%
df.columns
# Out:
# Index(['Timestamp', 'Which course are you currently enrolled in?',
#        'What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]',
#        'What motivated you to seek a computing class at CCM? [To keep current in computing skills]',
#        'What motivated you to seek a computing class at CCM? [Career Advancement]',
#        'What motivated you to seek a computing class at CCM? [Career Change]',
#        'What motivated you to seek a computing class at CCM? [Professional Development]',
#        'What motivated you to seek a computing class at CCM? [Job Displacement]',
#        'What motivated you to seek a computing class at CCM? [Relocation]',
#        'What motivated you to seek a computing class at CCM? [IT Industry Certifications]',
#        'What motivated you to seek a computing class at CCM? [Financial]',
#        'What motivated you to seek a computing class at CCM? [Personal Enrichment]',
# ...

# %% [markdown]
# ### **(c)** df.shape
# After I ran this property on the dataframe, it returned a tuple that displayed the shape of the dataset in rows, columns format. I found that there were 105 observations and there were 96 columns in this dataset using this property.

# %%
df.shape
# Out:
# (92, 71)

# %% [markdown]
# ### **(d)** df.dtypes
# After I ran this property on the dataframe, it returned the data type of every column of the dataset. With this command, I noticed that a majority of the dataset was an 'object' datatype.

# %%
df.dtypes
# Out:
# Timestamp                                                                                                                                    object
# Which course are you currently enrolled in?                                                                                                  object
# What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]                                      object
# What motivated you to seek a computing class at CCM? [To keep current in computing skills]                                                   object
# What motivated you to seek a computing class at CCM? [Career Advancement]                                                                    object
#                                                                                                                                               ...
# ...

# %% [markdown]
# ### **(e)** df.head()
# After I ran this function on the dataframe, I was given the first five responses in the dataset. With this command, I was able to see a glimpse of the dataset using the first five rows as a sample.

# %%
df.head()
# Out:
#                     Timestamp   Which course are you currently enrolled in?  \
# 0  2024/09/10 10:47:35 AM AST  CMP 126 Computer Technology and Applications
# 1  2024/09/10 11:00:05 AM AST  CMP 126 Computer Technology and Applications
# 2  2024/09/10 11:02:51 AM AST  CMP 126 Computer Technology and Applications
# 3  2024/09/10 11:05:25 AM AST  CMP 126 Computer Technology and Applications
# 4   2024/09/10 8:37:36 PM AST         CMP 101 Computer Information Literacy
#
#   What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   What motivated you to seek a computing class at CCM? [To keep current in computing skills]  \
# ...

# %%
# I noticed that you can customize the number of samples so I tried it out here!
df.head(3)
# Out:
#                     Timestamp   Which course are you currently enrolled in?  \
# 0  2024/09/10 10:47:35 AM AST  CMP 126 Computer Technology and Applications
# 1  2024/09/10 11:00:05 AM AST  CMP 126 Computer Technology and Applications
# 2  2024/09/10 11:02:51 AM AST  CMP 126 Computer Technology and Applications
#
#   What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
#
#   What motivated you to seek a computing class at CCM? [To keep current in computing skills]  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
#
#   What motivated you to seek a computing class at CCM? [Career Advancement]  \
# 0                                                Yes
# ...

# %% [markdown]
# ### **(f)** df.tail()
# After I ran this function on the dataframe, I was given the last five responses in the dataset. With this command, I was able to see a glimpse of the dataset using the last five rows as a sample.

# %%
df.tail()
# Out:
#                      Timestamp   Which course are you currently enrolled in?  \
# 87  2024/09/20 10:55:34 PM AST         CMP 101 Computer Information Literacy
# 88  2024/09/20 11:02:45 PM AST  CMP 126 Computer Technology and Applications
# 89  2024/09/20 11:07:16 PM AST  CMP 126 Computer Technology and Applications
# 90   2024/09/21 5:06:23 PM AST         CMP 101 Computer Information Literacy
# 91  2024/09/22 10:08:19 PM AST  CMP 126 Computer Technology and Applications
#
#    What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]  \
# 87                                                Yes
# 88                                                Yes
# 89                                                Yes
# 90                                                 No
# 91                                                Yes
#
#    What motivated you to seek a computing class at CCM? [To keep current in computing skills]  \
# ...

# %%
# I noticed that you can customize the number of samples so I tried it out here!
df.tail(3)
# Out:
#                      Timestamp   Which course are you currently enrolled in?  \
# 89  2024/09/20 11:07:16 PM AST  CMP 126 Computer Technology and Applications
# 90   2024/09/21 5:06:23 PM AST         CMP 101 Computer Information Literacy
# 91  2024/09/22 10:08:19 PM AST  CMP 126 Computer Technology and Applications
#
#    What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]  \
# 89                                                Yes
# 90                                                 No
# 91                                                Yes
#
#    What motivated you to seek a computing class at CCM? [To keep current in computing skills]  \
# 89                                                 No
# 90                                                Yes
# 91                                                Yes
#
#    What motivated you to seek a computing class at CCM? [Career Advancement]  \
# ...

# %% [markdown]
# ### **(g)** df.sample()
# After I ran this function on the dataframe, I was given a random observation inside of the dataset. However, I noticed that I was able to give it a parameter, so I was able to ask it for multiple random observations inside of the dataset as well. This was fun to play around with! I also applied the same parameter feature to the above commands as well.

# %%
df.sample()
# Out:
#                     Timestamp  Which course are you currently enrolled in?  \
# 39  2024/09/12 8:05:15 PM AST  CMP 135 Computer Concepts with Applications
#
#    What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]  \
# 39                                                Yes
#
#    What motivated you to seek a computing class at CCM? [To keep current in computing skills]  \
# 39                                                 No
#
#    What motivated you to seek a computing class at CCM? [Career Advancement]  \
# 39                                                 No
#
#    What motivated you to seek a computing class at CCM? [Career Change]  \
# 39                                                Yes
#
#    What motivated you to seek a computing class at CCM? [Professional Development]  \
# 39                                                Yes
#
#    What motivated you to seek a computing class at CCM? [Job Displacement]  \
# ...

# %%
# I noticed that you can customize the number of samples so I tried it out here!
df.sample(5)
# Out:
#                      Timestamp   Which course are you currently enrolled in?  \
# 58  2024/09/18 12:06:47 PM AST  CMP 126 Computer Technology and Applications
# 20  2024/09/12 11:30:41 AM AST   CMP 135 Computer Concepts with Applications
# 29  2024/09/12 11:32:31 AM AST   CMP 135 Computer Concepts with Applications
# 71  2024/09/19 12:15:33 PM AST  CMP 126 Computer Technology and Applications
# 36   2024/09/12 8:04:45 PM AST   CMP 135 Computer Concepts with Applications
#
#    What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]  \
# 58                                                Yes
# 20                                                Yes
# 29                                                Yes
# 71                                                Yes
# 36                                                Yes
#
#    What motivated you to seek a computing class at CCM? [To keep current in computing skills]  \
# ...

# %% [markdown]
# ### **(h)** df.info()
# After I ran this function on the dataframe, I noticed that it gave me the list of columns again and also gave me the column's corresponding index. Additionally, I noticed that it also gave the 'class', RangeIndex, DataTypes, and memory usage. I noticed now, more clearly, that there is only 1 column in the dataset that is not of type object, which is likely the one question that appeared in the summary() function!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                           --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                        92 non-null     object
# ...

# %% [markdown]
# ## 3. Perform data cleaning operations on the Project 1 dataset.
# These are the provided instructions for this portion of the assignment.
# * Rename the columns to a single, lower-case word. Use the underscore character to combine words, if needed.
# * The focus of this study is on recruitment of new students. Evaluate which features are important for the study. Remove the features that are not relevant or redundant.
# * Some of the features like Major and Race have redundancies. Clean and condense the values to have fewer different values. For example, perhaps collapse all engineering majors into Engineering.
# * Consider if there are other data cleaning actions you should take.

# %% [markdown]
# ### **(a)** Evaluate which features are important for the study. Remove the features that are not relevant or redundant.
# * I believe that the following columns are not important for the recruitment of new students.
#   * `Timestamp` - This is their submission date, which has nothing to do with recruitment.
#   * `Which course are you currently enrolled in?` - This is for students who are currently attending, and not important for recruiting.
#
# I thought about removing these columns: `Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all?`, `To what extent did the following impact your decision to attend County College of Morris?`, and `How did you hear about County College of Morris?` because they weren't specific to the program, but I decided to keep them because they would be able to help the chairperson be able to find the events they got the most enrollment from and use that for the future.

# %%
cleaning_df = df.drop(columns=['Timestamp', 'Which course are you currently enrolled in?'])

# %% [markdown]
# ### **(b)** Rename the columns to a single, lower-case word. Use the underscore character to combine words, if needed.
# I thought about taking each of the columns that were just answer choices to the same question and combining them, but then, I realised that it would be harder to read data from my Intro to Data Science class. I simply kept the same structure but I renamed all of the columns so it is easier to reference them instead of using the long question form!
#
# I structured the naming to be like this:
# `question`_`type` (example... `heard_ccm` would be a question and `website` would be a column of data to reference!)

# %%
cleaning_df.rename(columns={
    'How did you hear about County College of Morris  [CCM Web site]': 'heard_ccm_website',
    'How did you hear about County College of Morris  [Social Media]': 'heard_ccm_social_media',
    'How did you hear about County College of Morris  [Community Event]': 'heard_ccm_event',
    'How did you hear about County College of Morris  [Family member or friend]': 'heard_ccm_family_friend',
    'How did you hear about County College of Morris  [Current student]': 'heard_ccm_current_student',
    'How did you hear about County College of Morris  [Alumni]': 'heard_ccm_alumni',
    'How did you hear about County College of Morris  [High School Teacher]': 'heard_ccm_hs_teacher',
    'How did you hear about County College of Morris  [High School]': 'heard_ccm_hs',
    'How did you hear about County College of Morris  [In-app advertisement]': 'heard_ccm_ad',
    'How did you hear about County College of Morris  [Employer]': 'heard_ccm_employer',
    'How did you hear about County College of Morris  [Billboard]': 'heard_ccm_billboard',
    'How did you hear about County College of Morris  [Television]': 'heard_ccm_tv',
    'How did you hear about County College of Morris  [Radio]': 'heard_ccm_radio',
    'How did you hear about County College of Morris  [Home mailer]': 'heard_ccm_mailer',
    'How did you hear about County College of Morris  [Other]': 'heard_ccm_other',
    'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]': 'impact_affordable_cost',
    'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]': 'impact_location',
    'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]': 'impact_program_choice',
    'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]': 'impact_online_offerings',
    'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]': 'impact_family_referral',
    'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]': 'impact_faculty_staff',
    'To what extent did the following impact your decision to attend County College of Morris? [College reputation]': 'impact_reputation',
    'To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]': 'impact_financial_aid',
    'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]': 'impact_scholarships',
    'To what extent did the following impact your decision to attend County College of Morris? [Transfer student]': 'impact_transfer',
    'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]': 'impact_small_class_sizes',
    'To what extent did the following impact your decision to attend County College of Morris? [Extra curricula opportunities]': 'impact_extra_curricula',
    'To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]': 'impact_transfer_credits',
    'To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]': 'impact_negative_experience',
    'To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]': 'impact_nj_stars',
    'To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]': 'impact_transfer_ccm_credits',
    'To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]': 'impact_college_credit_in_highschool',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]': 'event_open_house',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]': 'event_instant_decision',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]': 'event_info_session_on_campus',
    "Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [TItan's Tuesday Virtual Information Session]": 'event_virtual_info_session',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]': 'event_women_who_dare',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]': 'event_regional_fair',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]': 'event_high_school_sharetime',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]': 'event_challenger_program',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]': 'event_cybersecurity_program',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]': 'event_hs_info_session',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]': 'event_hs_campus_visit',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]': 'event_individual_campus_visit',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]': 'event_workforce_class',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]': 'event_corporate_training',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]': 'event_teen_arts',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]': 'event_summer_camp',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Hour of Code]': 'event_hour_of_code',
    'What motivated you to seek a computing class at CCM? [To keep current in computing skills]': 'motivation_keep_current',
    'What motivated you to seek a computing class at CCM? [Curiosity]': 'motivation_curiosity',
    'What motivated you to seek a computing class at CCM? [Personal Enrichment]': 'motivation_personal_enrichment',
    'What motivated you to seek a computing class at CCM? [Career Advancement]': 'motivation_career_advancement',
    'What motivated you to seek a computing class at CCM? [Career Change]': 'motivation_career_change',
    'What motivated you to seek a computing class at CCM? [Professional Development]': 'motivation_professional_dev',
    'What motivated you to seek a computing class at CCM? [Job Displacement]': 'motivation_job_displacement',
    'What motivated you to seek a computing class at CCM? [Financial]': 'motivation_financial',
    'What motivated you to seek a computing class at CCM? [Relocation]': 'motivation_relocation',
    'What motivated you to seek a computing class at CCM? [IT Industry Certifications]': 'motivation_it_certifications',
    "What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]": "motivation_required_class_for_degree",
    "To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]": "extent_impact_hs_computing_class",
    "To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]": "extent_impact_hs_computing_club",
    "To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]": "extent_impact_computing_competitions",
    "To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]": "extent_impact_afterschool_computing_camp",
    "To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]": "extent_impact_summer_computing_camp",
    "To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]": "extent_impact_ap_computing_class",
    "To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]": "extent_impact_dual_enrollment_computing_class",
    "To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]": "extent_impact_family_or_friend_influence",
    "To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]": "extent_impact_family_working_in_computing",
    "To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]": "extent_impact_hs_teacher_guidance",
    "To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]": "extent_impact_employer_influence",
    "To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [CCM faculty member]": "extent_impact_ccm_faculty",
    "To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [CCM advisor/counselor]": "extent_impact_ccm_advisor_counselor",
    "What degree program are you currently enrolled in?": "program",
    "Did you receive information about our computing course from any of the following sources? [High school guidance counselor]": "info_from_hs_counselor",
    "Did you receive information about our computing course from any of the following sources? [CCM Information Technologies Website]": "info_from_ccm_it_website",
    "Did you receive information about our computing course from any of the following sources? [CCM Admissions]": "info_from_ccm_admissions",
    "Did you receive information about our computing course from any of the following sources? [CCM advisor/counselor]": "info_from_ccm_advisor",
    "Did you receive information about our computing course from any of the following sources? [Employer]": "info_from_employer",
    "Did you receive information about our computing course from any of the following sources? [CCM Workforce Development]": "info_from_ccm_workforce",
    "Did you receive information about our computing course from any of the following sources? [NJ Workforce Development Program]": "info_from_nj_workforce",
    "Did you receive information about our computing course from any of the following sources? [Other]": "info_from_other",
    "On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?": "more_courses",
    "If you answered that you were interested in taking more computing classes, which ones interest you most? [Web Development]": "interest_web_development",
    "If you answered that you were interested in taking more computing classes, which ones interest you most? [CyberSecurity]": "interest_cybersecurity",
    "If you answered that you were interested in taking more computing classes, which ones interest you most? [App Development]": "interest_app_development",
    "If you answered that you were interested in taking more computing classes, which ones interest you most? [Data Analytics]": "interest_data_analytics",
    "If you answered that you were interested in taking more computing classes, which ones interest you most? [Machine Learning/Artificial Intelligence]": "interest_ml_ai",
    "If you answered that you were interested in taking more computing classes, which ones interest you most? [Computer Programming]": "interest_computer_programming",
    "If you answered that you were interested in taking more computing classes, which ones interest you most? [Game Design]": "interest_game_design",
    "If you answered that you were interested in taking more computing classes, which ones interest you most? [Hardware Installation & Repair]": "interest_hardware_repair",
    "Gender": "gender",
    "Race/ethnicity": "race",
    "Age ": "age"
    }, inplace=True)

# %% [markdown]
# ### **(c)** Some of the features like Major and Race have redundancies. Clean and condense the values to have fewer different values. For example, perhaps collapse all engineering majors into Engineering.
# I went ahead and complied a list of all of majors and then used a dictionary to rename certain values to be either **Nursing**, **Psychology**, **Liberal Arts**, **Criminal Justice**, or **Education**.

# %%
cleaning_df['program'] = cleaning_df['program'].map({
    "Nursing": "Nursing",
    "Radiography": "Nursing",
    "Public Health": "Nursing",
    "Psychology": "Psychology",
    "Human Resources/ Psychology": "Psychology",
    "Liberal Arts": "Liberal Arts",
    "Communication": "Liberal Arts",
    "Broadcasting Arts and Technology": "Liberal Arts",
    "Music Technology": "Liberal Arts",
    "Music recording": "Liberal Arts",
    "Theatre Technology": "Liberal Arts",
    "Musical Theatre": "Liberal Arts",
    "Criminal Justice": "Criminal Justice",
    "Fire Science Technologies": "Criminal Justice",
    "Exercise Science": "Nursing",
    "Child and Family Studies": "Education",
    "Early Childhood Education": "Education",
    "World Language": "Liberal Arts",
    "psychology , liberal arts": "Liberal Arts",
})

# %% [markdown]
# For race, I decided to take each of the 2+ races and put them into 1 category, called "Multi-Racial".

# %%
mask = cleaning_df['race'].str.contains(';')
cleaning_df.loc[mask, 'race'] = 'Multi-Racial'

# %% [markdown]
# ### The final dataset...
# I will now print out the final cleaned dataset after the 4 modifications I have made above.

# %%
cleaning_df
# Out:
#    motivation_required_class_for_degree motivation_keep_current  \
# 0                                    No                     Yes
# 1                                   Yes                     Yes
# 2                                   Yes                     Yes
# 3                                    No                     Yes
# 4                                   Yes                     Yes
# ..                                  ...                     ...
# 87                                  Yes                     Yes
# 88                                  Yes                     Yes
# 89                                  Yes                      No
# 90                                   No                     Yes
# 91                                  Yes                     Yes
#
#    motivation_career_advancement motivation_career_change  \
# 0                            Yes                      Yes
# 1                            Yes                       No
# ...

# %% [markdown]
# ## 4. Save your cleaned dataset as a new CSV file.
# I will submit what is exported to the file below!

# %%
cleaning_df.to_csv('CleanedFall2024.csv', index=False)
